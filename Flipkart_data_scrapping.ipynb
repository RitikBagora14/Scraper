# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
for i in range(2,10):
    url = "https://www.flipkart.com/search?q=analog+watch+for+men&sid=r18%2Cf13&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=analog+watch+for+men%7CWrist+Watches&requestId=0e3b7518-17fd-4d8c-95d1-525284701299&as-backfill=on&page=" + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    np = soup.find('a', class_='_9QVEpD').get("href")
    cnp = "https://www.flipkart.com"+np
    print(cnp)
# Out:
# https://www.flipkart.com/search?q=analog+watch+for+men&sid=r18%2Cf13&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=analog+watch+for+men%7CWrist+Watches&requestId=0e3b7518-17fd-4d8c-95d1-525284701299&as-backfill=on&page=1
# https://www.flipkart.com/search?q=analog+watch+for+men&sid=r18%2Cf13&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=analog+watch+for+men%7CWrist+Watches&requestId=0e3b7518-17fd-4d8c-95d1-525284701299&as-backfill=on&page=2
# ...

# %%
Product_name = []
description = []
reviews = []
ratings = []
for i in range(1,12):
    url = "https://www.flipkart.com/search?q=analog+watch+for+men&sid=r18%2Cf13&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_sc_na_na&as-pos=1&as-type=RECENT&suggestionId=analog+watch+for+men%7CWrist+Watches&requestId=0e3b7518-17fd-4d8c-95d1-525284701299&as-backfill=on&page=" + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    names = soup.find_all("div", class_= "syl9yP")
    for i in names:
        name = i.text
        Product_name.append(name)
    print(Product_name)
# Out:
# ['RUSTET', 'LOIS CARON', 'Allen Solly', 'Reboot', 'Reboot', 'EVRGLOW', 'Reboot', 'Reboot', 'PETER ENGLAND', 'PETER ENGLAND', 'ANALOGUE', 'Espoir', 'Allen Solly', 'Reboot', 'PETER ENGLAND', 'PETER ENGLAND', 'RUSTET', 'FOGG', 'Reboot', 'PETER ENGLAND', 'FRANKTIME', 'hrnt', 'PROVOGUE', 'PETER ENGLAND', 'CASIO', 'PETER ENGLAND', 'LORENZ', 'LIMESTONE', 'Reboot', 'Allen Solly', 'Casado', 'HYMT', 'PETER ENGLAND', 'TIMEX', 'Reboot', 'TIMEX', 'IIK Collection', 'KILLER', 'PETER ENGLAND', 'PROVOGUE']
# ...
